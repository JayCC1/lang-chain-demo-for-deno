// %%
import { PromptTemplate } from "@langchain/core/prompts";

const greetingTemplate = new PromptTemplate({
    inputVariables: [],
    template: "Hello, World!",
});

const formattedGreeting = await greetingTemplate.format();
console.log(formattedGreeting);
// Out:
// Hello, World!
